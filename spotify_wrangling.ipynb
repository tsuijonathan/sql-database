# %% [markdown]
# #Load Modules

# %%
from dotenv import load_dotenv
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pycountry
from collections import defaultdict
import pandas as pd
import time
from spotipy.exceptions import SpotifyException
from collections import Counter

# %% [markdown]
# #Log in Spotify API

# %%
with open(".env", "w") as env_file:
    env_file.write("SPOTIPY_CLIENT_ID=63799c6d926d4adfb02144afd910b085\n")
    env_file.write("SPOTIPY_CLIENT_SECRET=7ada6a33b195445aaa3962da45db695a\n")

# %%
# Load environment variables from the .env file
load_dotenv()

# Retrieve credentials from environment variables
client_id = os.getenv("SPOTIPY_CLIENT_ID")
client_secret = os.getenv("SPOTIPY_CLIENT_SECRET")

# Initialize Spotipy with client credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
#testing the login
featured_playlists = sp.featured_playlists(limit=5)
for playlist in featured_playlists['playlists']['items']:
    print(playlist['name'], "-", playlist['id'])
# Out:
# Éxitos España - 37i9dQZF1DXaxEKcoCdWHD
# PEGAO - 37i9dQZF1DX1HCSfq0nSal
# Viva Latino - 37i9dQZF1DX10zKzsJ2jva
# Viral España 2024 - 37i9dQZF1DWVJv1UsWItkB
# Pop con Ñ - 37i9dQZF1DX3sCT1ItXgNd

# %% [markdown]
# #Data wrangling

# %%
def get_country_codes():
    """
    Generate a flattened list of country codes from the regions dictionary we created.
    
    Returns:
    - country_codes (list): List of ISO country codes from the regions dictionary.
    """
    regions = {
    "North America": 'US',
    "South America": 'BR', 
    "Europe": {
        "Western Europe": 'DE', 
        "Northern Europe": 'GB', 
        "Southern Europe": 'IT', 
    },
    "Africa": {
        "North Africa": 'EG',
        "Sub-Saharan Africa": 'NG', 
    },
    "Oceania": 'AU',
    "Asia": {
        "Southeast Asia": 'ID',
        "South Asia": 'IN',
    },
    "Middle East": 'SA', 
    }
    
    country_codes = []
    for value in regions.values():
        if isinstance(value, dict):
            country_codes.extend(value.values())
        else:
            country_codes.append(value)
    return country_codes

def get_top_playlist_id_for_country(sp, country_code):
    """
    Search for the top "Top 50" playlist for the specified country and return its ID.
    
    Parameters:
    - sp (Spotify): Authenticated Spotify client object.
    - country_code (str): ISO country code to search for the top playlist.

    Returns:
    - playlist_id (str): ID of the top playlist for the specified country, or None if not found.
    """
    try:
        results = sp.search(q=f"Top 50 - {country_code}", type="playlist", limit=1)
        return results['playlists']['items'][0]['id']
    except Exception as e:
        print(f"Error fetching playlist for {country_code}: {e}")
        return None

def get_artists_from_playlist(sp, playlist_id, country_code):
    """
    Extract unique artists from the top 50 playlist and return a list of artist data dictionaries.
    
    Parameters:
    - sp (Spotify): Authenticated Spotify client object.
    - playlist_id (str): Spotify playlist ID to retrieve tracks from.
    - country_code (str): ISO country code associated with the playlist for tagging the artists.

    Returns:
    - artists_list (list): List of dictionaries, each containing information about a unique artist from the playlist.
                           Each dictionary has keys 'artist_id', 'name', 'popularity_rating', 'genre', and 'country_code'.
    """
    artists = {}
    try:
        playlist_tracks = sp.playlist_tracks(playlist_id, limit=50)
        
        for item in playlist_tracks['items']:
            track = item['track']
            if track:
                for artist in track['artists']:
                    artist_id = artist['id']
                    artist_name = artist['name']
                    artist_details = sp.artist(artist_id)
                    popularity = artist_details['popularity']
                    genres = artist_details['genres']
                    first_genre = genres[0] if genres else ''  # Only the first genre
                    
                    if artist_id not in artists:  # Avoid duplicates
                        artists[artist_id] = {
                            'artist_id': artist_id,
                            'name': artist_name,
                            'popularity_rating': popularity,
                            'genre': first_genre,
                            'country_code': country_code
                        }

        return list(artists.values())[:25]  # Limit to top 25 unique artists
    except Exception as e:
        print(f"Error processing playlist {playlist_id}: {e}")
        return []

def collect_data(sp, country_codes):
    """
    Collect artist, country, and festival data for each country code by accessing top playlists.
    
    Parameters:
    - sp (Spotify): Authenticated Spotify client object.
    - country_codes (list): List of ISO country codes to collect data for.

    Returns:
    - artist_data (list): List of dictionaries containing artist information.
    - country_data (list): List of dictionaries containing artist-to-country mapping.
    - festival_data (list): List of dictionaries containing country-to-artist name mapping for festival data.
    """
    artist_data = []
    country_data = []
    festival_data = []

    for country_code in country_codes:
        playlist_id = get_top_playlist_id_for_country(sp, country_code)
        
        if playlist_id:
            top_artists = get_artists_from_playlist(sp, playlist_id, country_code)
            for artist in top_artists:
                # Append artist data
                artist_data.append(artist)

                # Append country data
                country_data.append({
                    'artist_id': artist['artist_id'],
                    'country_code': artist['country_code']
                })

                # Append festival data with artist name instead of artist ID
                festival_data.append({
                    'country_code': artist['country_code'],
                    'artist_name': artist['name']
                })

    return artist_data, country_data, festival_data

def save_to_csv(artist_data, country_data, festival_data):
    """
    Save the collected artist, country, and festival data to CSV files.
    
    Parameters:
    - artist_data (list): List of dictionaries containing artist information.
    - country_data (list): List of dictionaries containing artist-to-country mapping.
    - festival_data (list): List of dictionaries containing country-to-artist name mapping for festival data.
    
    Output:
    - Three CSV files ('artist.csv', 'country.csv', 'festival.csv') saved in the current directory.
    """
    artist_df = pd.DataFrame(artist_data).drop_duplicates()
    country_df = pd.DataFrame(country_data).drop_duplicates()
    festival_df = pd.DataFrame(festival_data).drop_duplicates()

    artist_df.to_csv('artist.csv', index=False)
    country_df.to_csv('country.csv', index=False)
    festival_df.to_csv('festival.csv', index=False)
    print("CSV files created for artist, country, and festival tables.")

# Get country codes
country_codes = get_country_codes()

# Collect data
artist_data, country_data, festival_data = collect_data(sp, country_codes)

# Save data to CSV files
save_to_csv(artist_data, country_data, festival_data)
# Out:
# CSV files created for artist, country, and festival tables.

# %%
display(artist_df)
display(country_df)
display(festival_df)

# %% [markdown]
# #EDA

# %%
#dataframe cleaning
artist_df_cleaned = artist_df.dropna()
artist_df_cleaned.to_csv('artist_cleaned.csv', index=False)

# %%
# Load the datasets
artist_df = pd.read_csv('artist_cleaned.csv')
country_df = pd.read_csv('country.csv')
festival_df = pd.read_csv('festival.csv')
top_genres_df = pd.read_csv('top_genres_cleaned.csv')

# %%
# Organizing genres by country using the cleaned artist_df
genres_by_country_cleaned = artist_df_cleaned.groupby('country_code')['genre'].apply(list)

# Calculating the top 3 genres for each country in list format for easy retrieval
top_genres_by_country_cleaned = {
    country: [genre for genre, count in Counter(genres).most_common(3)]
    for country, genres in genres_by_country_cleaned.items()
}

# Converting the result to a DataFrame with genres as a list
top_genres_list_df_cleaned = pd.DataFrame([
    {'country_code': country, 'top_genres': genres}
    for country, genres in top_genres_by_country_cleaned.items()
])

# %%
# Saving cleaned top_genres df
#top_genres_list_df_cleaned.to_csv('top_genres_cleaned.csv', index=False)

# %%
#displaying top_genres
top_genres_list_df_cleaned
# Out:
#    country_code                                         top_genres
# 0            AU  [contemporary country, classic oklahoma countr...
# 1            BR      [hip hop, canadian contemporary r&b, art pop]
# 2            DE      [art pop, hip hop, canadian contemporary r&b]
# 3            EG   [arab pop, egyptian hip hop, egyptian viral pop]
# 4            GB         [glam rock, adult standards, classic rock]
# 5            ID  [italian hip hop, italian pop, italian adult pop]
# 6            IN  [contemporary country, modern country pop, dfw...
# 7            IT      [art pop, hip hop, canadian contemporary r&b]
# 8            NG      [art pop, hip hop, canadian contemporary r&b]
# 9            SA      [art pop, hip hop, canadian contemporary r&b]
# 10           US      [art pop, hip hop, canadian contemporary r&b]

# %%
# Sort by country, genre, and popularity rating
top_artists_sorted = artist_df_cleaned.sort_values(['country_code', 'genre', 'popularity_rating'], ascending=[True, True, False])

# Retrieve top 15 artists per genre within each country
top_artists_by_genre_country = top_artists_sorted.groupby(['country_code', 'genre']).head(15)

# Display the top artists organized by country and genre
top_artists_by_genre_country
# Out:
#                   artist_id                name  popularity_rating  \
# 195  3oVcF3VdpMuvMvLLyHPT4t      Sierra Ferrell                 65
# 187  32vWCbZh0xZ4o9gkz4PsEU        Dolly Parton                 75
# 191  1UTPBmNbXNTittyMJrNkvw       Blake Shelton                 73
# 199  3THMgU4KdL7LlO5TEREs2g          Joe Diffie                 61
# 180  4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 186  718COspgdWOnwOFpJHRZHS          Luke Combs                 87
# 176  4YLtscXsxbVgi031ovDDdh     Chris Stapleton                 83
# 188  6tPHARSq45lQ8BSALCfkFC       Lainey Wilson                 76
# 196  5QNm7E7RU2m64l6Gliu8Oy               HARDY                 75
# 177  6roFdX1y5BYSbp60OTJWMd          Tim McGraw                 73
# 184  13YmWQJFwgZrd4bf5IjMY4        Brad Paisley                 67
# 183  6ZV6lGY0prbqpTD0Md8i29     Scotty McCreery                 60
# 190  2dyeCWctcFRt3Pha76ONgb  Hank Williams, Jr.                 69
# 182  5aizOVB0aFinBgezLPkhnm      Callista Clark                 40
# 178  19k8AgwwTSxeaxkOuCQEJs          Jelly Roll                 83
# 175  246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 194  1ZN1c1qWEGZNX1pGeKCPpf       Billy Strings                 66
# 193  4GGfAshSkqoxpZdoaHm7ky              ERNEST                 73
# 198  4Y8LpEiP4uKTP02lSYEWJV             HIXTAPE                 64
# 197  2RQXRUsr4IW1f3mKyKsy4B          Noah Kahan                 86
# 30   4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams                 90
# 42   6Jrxnp0JgqmeUX1veU591p           Santigold                 72
# 35   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish                 96
# 31   1HY2Jd0NmPuamShAr6KMms           Lady Gaga                 92
# 44   699OTQXzgjhIYAHMy9RyPD       Playboi Carti                 90
# 34   1iCnM8foFssWlPRLfAbIwo          Gigi Perez                 81
# 43   1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd                 96
# 26   20wkVLutqVOYrc0kxFs7rA       Daniel Caesar                 87
# 45   1U1el3k54VvEUzo3ybLPlM          Kali Uchis                 86
# 46   4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 48   0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida                 91
# 47   3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon                 87
# 32   0du5cEVh5yTK9QJze8zA0C          Bruno Mars                 96
# 49   246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 41   5IcR3N7QB1j6KBL8eImZ8m         ScHoolboy Q                 78
# 25   4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator                 95
# 29   55Aa2cqylxrFIXC767Z865           Lil Wayne                 88
# 40   7GlBOeep6PqTfFi59PTUUN       Chappell Roan                 89
# 39   1oSPZhvZMIrWW5I41kPkkY               Jimin                 89
# 37   3eVa5w3URK5duf6eyVDbu9                ROSÉ                 84
# 36   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter                 94
# 27   2qoQgPAilErOKCwE2Y8wOG            GloRilla                 82
# 28   3DbwFQlvLxRSi2uX8mf81A           Sexyy Red                 80
# 38   67FB4n52MgexGQIG8s0yUH          Lola Young                 74
# 50   4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams                 90
# 59   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish                 96
# 51   1HY2Jd0NmPuamShAr6KMms           Lady Gaga                 92
# 64   699OTQXzgjhIYAHMy9RyPD       Playboi Carti                 90
# 53   1iCnM8foFssWlPRLfAbIwo          Gigi Perez                 81
# 63   1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd                 96
# 58   20wkVLutqVOYrc0kxFs7rA       Daniel Caesar                 87
# 66   1U1el3k54VvEUzo3ybLPlM          Kali Uchis                 86
# 72   4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 71   0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida                 91
# 70   3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon                 87
# 52   0du5cEVh5yTK9QJze8zA0C          Bruno Mars                 96
# 73   246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 54   4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator                 95
# 57   55Aa2cqylxrFIXC767Z865           Lil Wayne                 88
# 65   7GlBOeep6PqTfFi59PTUUN       Chappell Roan                 89
# 60   1oSPZhvZMIrWW5I41kPkkY               Jimin                 89
# 62   3eVa5w3URK5duf6eyVDbu9                ROSÉ                 84
# 69   3y2cIKLjiOlp1Np37WiUdH           Shaboozey                 80
# 61   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter                 94
# 74   22wbnEMDvgVIAGdFeek6ET        Benson Boone                 86
# 55   2qoQgPAilErOKCwE2Y8wOG            GloRilla                 82
# 56   3DbwFQlvLxRSi2uX8mf81A           Sexyy Red                 80
# 67   67FB4n52MgexGQIG8s0yUH          Lola Young                 74
# 144  2GVksDv9UpY60i4CvytrZK            Cairokee                 62
# 134  5rCq30EbJ3DfZPKybGZj8F        Tamer Ashour                 64
# 140  5LtHZB7vU02HtNoOzNcVhc          Ramy Sabry                 63
# 142  6bb9VI1PpPTEmdgcgjTppX      Mohamed Hamaki                 61
# 138  5HczG7gdd89oDKY0CUyPof         Wael Jassar                 60
# 126  2KJgliIl1dMyeOMyCcnYv7        Bahaa Sultan                 59
# 143  0IiR4LJwslf6HBSdk9W3Dg              Angham                 59
# 147  2iToE4LH0W9zs4hVw3A7m6   Mahmoud El Leithy                 57
# 149  5OaC42gxOxSYgfmmSxe672               Farid                 50
# 135  2PM82jOCB674w4BL08zFVS     Muslim - مُسلِم                 62
# 145  2yV4zQzvNPMyHncf60u9sr         Lella Fadda                 47
# 141  4BKC2HOGEqtYz2Xbgp9N1q                Wegz                 61
# 127  7yBuSjd5Z3w7acodk51evR              Afroto                 60
# 132  5764EiAfWT26wi1CdLcnwz              Shehab                 58
# 146  4o6vIkdmHiEXZOesrJj3KO             Abyusif                 56
# 148  2KjiHtx0h8tyJXbg8aYRgu          Essam Sasa                 65
# 133  5QKGejJMncXUNUb9pUFbEf              TUL8TE                 64
# 131  3mUUUQDWnVlttF1yERxmPQ              Ilmond                 60
# 130  5CSaIf8OAstAYE5oqQeS15      Magdy El Zahar                 58
# 125  4IMgqWorWJUqUlbULGdoBa     Youssif Elashry                 54
# 139  25P1GMgHepq6rkzRwg2DcB       Eslam Kabonga                 60
# 136  3gCqbhXmiSto3R8U9YZcZM     Reda El Bahrawy                 56
# 95   1GxkXlMwML1oSg5eLPiAz3       Michael Bublé                 79
# 94   7v4imS0moSyGdXyLgVTIV7       Nat King Cole                 74
# 76   21LGsW7bziR4Ledx7WZ1Wf       Johnny Mathis                 57
# 82   0GByy3DcfbQwDvXGCWmzv9          Pretenders                 64
# 86   5D5J2cMoaGHFaipckBl5xZ  Vienna Boys' Choir                 39
# 99   6lOC7lwSO1ql4Gc2Y3QObY             East 17                 47
# 83   5lKZWd6HiSCLfnDGrq9RAm         Leona Lewis                 67
# 91   2wzMOQwNT6ZvVB4amvhFAH          The Pogues                 60
# 90   1dfeR4HaWDbWqFHLkxsg1d               Queen                 86
# 93   4STHEaNw4mPZ2tzheohgXB      Paul McCartney                 74
# 84   4x1nvY2FN8jxqAFA0DA02H         John Lennon                 72
# 81   0wi4yTYlGtEnbGo4ltZTib     Shakin' Stevens                 59
# 97   32WkQRZEVKSzVAAYqukAEA              Lady A                 68
# 96   4iHNK0tOyZPYnBU7nGAgpQ        Mariah Carey                 81
# 89   12EtLdLfJ41vUOoVzPZIUy         Girls Aloud                 55
# 85   2s4tjL6W3qrblOe0raIzwJ            Yoko Ono                 58
# 77   3PhoLpVuITZKcymswpck5b          Elton John                 84
# 80   10n5lhNDoSMUHWLlnST1yw               Slade                 54
# 78   7823Dim2TzjiQQ9wRQxyi9             Wizzard                 47
# 75   3cqIsBnzV3BabbPWKz8Txf                 Mud                 45
# 79   5lpH0xAS4fVfLkACg9DAuM               Wham!                 73
# 92   6UlNIFEuWlBqb4TvlVCekq      Kirsty MacColl                 55
# 98   6Uw88LgaxdanDItfR0JyJ8           Greg Lake                 34
# 218  7cdIY4mDfM1dbjgl7s2fGR        Sal Da Vinci                 61
# 203  2PEMswqQspTSsAltdeF5kO        Simba La Rue                 76
# 220  6PsQc21YZU7WNfiODG69Qk            Tony Boy                 76
# 214  396Jr76018oUMR6QBnqT8T    Cesare Cremonini                 68
# 223  76UCIJTB0jcJvBaL0CdIqx      Takagi & Ketra                 68
# 222  0lI3rF4hi4op6UxqlLHPzv       Achille Lauro                 66
# 209  27LlKWxS3KXW7RRAxN5S8s             Geolier                 79
# 216  0jdNdfi4vAuVi7a6cPDFBM               Lazza                 79
# 207  0EUR8jz8L936AEbV2Spkca            Kid Yugi                 78
# 212  7K80yOTC0Id95gRaOxDG5u                ANNA                 76
# 219  2E6AK3UPEGCvjnzuygCh2h        Night Skinny                 75
# 221  5SulO4l40qDuV9zUGLZx7n          Capo Plaza                 75
# 213  4w9mPW732RnZkoqsy3lRsg         Niky Savage                 68
# 215  2pzFTbri7ew8mW2CbYpCNq               Astro                 68
# 208  3yGA8yyowtKVXgNIXguMfz          Lele Blade                 67
# 224  3wDn3kW2zDRLnaQAnX0S3x         Dat Boi Dee                 66
# 205  0hk4xVujcyOr6USD95wcWb           Sick Luke                 65
# 200  25u1DN0MwQVSav4XoJS7hl                Olly                 73
# 202  4rj3KWaLAnuxgtMMkypZhf                JVLI                 73
# 201  1A6HBLulvBFzNtlMb7b08f      Angelina Mango                 67
# 206  7GacyaFUp0qkEJglERX9N7                Alfa                 67
# 217  790FomKkXshlbRYZFtlgla             KAROL G                 91
# 236  3oSJ7TBVCWMDMiYjXNiCKE          Kane Brown                 76
# 235  64KEffDW9EtZ1y2vBYgq8T          Marshmello                 84
# 229  40ZNYROS4zLfyyBSs2PGe2          Zach Bryan                 91
# 230  70kkdajctXSbqSMJbQO424     Kacey Musgraves                 77
# 227  4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 231  718COspgdWOnwOFpJHRZHS          Luke Combs                 87
# 237  4YLtscXsxbVgi031ovDDdh     Chris Stapleton                 83
# 232  5Ppie0uPnbnvGBYRwYmlt0       Megan Moroney                 77
# 240  2QMsj4XJ7ne2hojxt6v5eb         Riley Green                 77
# 244  6tPHARSq45lQ8BSALCfkFC       Lainey Wilson                 76
# 247  3RqBeV12Tt7A8xH3zBDDUF    Kelsea Ballerini                 74
# 243  19k8AgwwTSxeaxkOuCQEJs          Jelly Roll                 83
# 226  246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 225  3y2cIKLjiOlp1Np37WiUdH           Shaboozey                 80
# 239  6BRxQ8cD3eqnrVj6WKDok8        Ella Langley                 74
# 233  4GGfAshSkqoxpZdoaHm7ky              ERNEST                 73
# 238  4sCKpwwEsgReZxjtKFm2A0      Tucker Wetmore                 71
# 249  0ChjBYedhZTQnWZWQYg15U        Bryan Martin                 70
# 245  63wjVVauFUQ4gBw6QXTT5N        Tyler Braden                 67
# 242  6TIYQ3jFPwQSRmorSezPxX                 mgk                 79
# 234  6vWDO969PvNqNYHIOW5v0m             Beyoncé                 87
# 248  2RQXRUsr4IW1f3mKyKsy4B          Noah Kahan                 86
# 100  4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams                 90
# 109  6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish                 96
# 101  1HY2Jd0NmPuamShAr6KMms           Lady Gaga                 92
# 114  699OTQXzgjhIYAHMy9RyPD       Playboi Carti                 90
# 103  1iCnM8foFssWlPRLfAbIwo          Gigi Perez                 81
# 113  1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd                 96
# 108  20wkVLutqVOYrc0kxFs7rA       Daniel Caesar                 87
# 116  1U1el3k54VvEUzo3ybLPlM          Kali Uchis                 86
# 122  4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 121  0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida                 91
# 120  3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon                 87
# 102  0du5cEVh5yTK9QJze8zA0C          Bruno Mars                 96
# 123  246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 104  4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator                 95
# 107  55Aa2cqylxrFIXC767Z865           Lil Wayne                 88
# 115  7GlBOeep6PqTfFi59PTUUN       Chappell Roan                 89
# 110  1oSPZhvZMIrWW5I41kPkkY               Jimin                 89
# 112  3eVa5w3URK5duf6eyVDbu9                ROSÉ                 84
# 119  3y2cIKLjiOlp1Np37WiUdH           Shaboozey                 80
# 111  74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter                 94
# 124  22wbnEMDvgVIAGdFeek6ET        Benson Boone                 86
# 105  2qoQgPAilErOKCwE2Y8wOG            GloRilla                 82
# 106  3DbwFQlvLxRSi2uX8mf81A           Sexyy Red                 80
# 117  67FB4n52MgexGQIG8s0yUH          Lola Young                 74
# 150  4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams                 90
# 159  6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish                 96
# 151  1HY2Jd0NmPuamShAr6KMms           Lady Gaga                 92
# 164  699OTQXzgjhIYAHMy9RyPD       Playboi Carti                 90
# 153  1iCnM8foFssWlPRLfAbIwo          Gigi Perez                 81
# 163  1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd                 96
# 158  20wkVLutqVOYrc0kxFs7rA       Daniel Caesar                 87
# 166  1U1el3k54VvEUzo3ybLPlM          Kali Uchis                 86
# 172  4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 171  0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida                 91
# 170  3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon                 87
# 152  0du5cEVh5yTK9QJze8zA0C          Bruno Mars                 96
# 173  246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 154  4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator                 95
# 157  55Aa2cqylxrFIXC767Z865           Lil Wayne                 88
# 165  7GlBOeep6PqTfFi59PTUUN       Chappell Roan                 89
# 160  1oSPZhvZMIrWW5I41kPkkY               Jimin                 89
# 162  3eVa5w3URK5duf6eyVDbu9                ROSÉ                 84
# 169  3y2cIKLjiOlp1Np37WiUdH           Shaboozey                 80
# 161  74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter                 94
# 174  22wbnEMDvgVIAGdFeek6ET        Benson Boone                 86
# 155  2qoQgPAilErOKCwE2Y8wOG            GloRilla                 82
# 156  3DbwFQlvLxRSi2uX8mf81A           Sexyy Red                 80
# 167  67FB4n52MgexGQIG8s0yUH          Lola Young                 74
# 250  4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams                 90
# 259  6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish                 96
# 251  1HY2Jd0NmPuamShAr6KMms           Lady Gaga                 92
# 264  699OTQXzgjhIYAHMy9RyPD       Playboi Carti                 90
# 253  1iCnM8foFssWlPRLfAbIwo          Gigi Perez                 81
# 263  1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd                 96
# 258  20wkVLutqVOYrc0kxFs7rA       Daniel Caesar                 87
# 266  1U1el3k54VvEUzo3ybLPlM          Kali Uchis                 86
# 272  4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 271  0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida                 91
# 270  3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon                 87
# 252  0du5cEVh5yTK9QJze8zA0C          Bruno Mars                 96
# 273  246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 254  4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator                 95
# 257  55Aa2cqylxrFIXC767Z865           Lil Wayne                 88
# 265  7GlBOeep6PqTfFi59PTUUN       Chappell Roan                 89
# 260  1oSPZhvZMIrWW5I41kPkkY               Jimin                 89
# 262  3eVa5w3URK5duf6eyVDbu9                ROSÉ                 84
# 269  3y2cIKLjiOlp1Np37WiUdH           Shaboozey                 80
# 261  74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter                 94
# 274  22wbnEMDvgVIAGdFeek6ET        Benson Boone                 86
# 255  2qoQgPAilErOKCwE2Y8wOG            GloRilla                 82
# 256  3DbwFQlvLxRSi2uX8mf81A           Sexyy Red                 80
# 267  67FB4n52MgexGQIG8s0yUH          Lola Young                 74
# 0    4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams                 90
# 9    6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish                 96
# 1    1HY2Jd0NmPuamShAr6KMms           Lady Gaga                 92
# 14   699OTQXzgjhIYAHMy9RyPD       Playboi Carti                 90
# 3    1iCnM8foFssWlPRLfAbIwo          Gigi Perez                 81
# 13   1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd                 96
# 8    20wkVLutqVOYrc0kxFs7rA       Daniel Caesar                 87
# 16   1U1el3k54VvEUzo3ybLPlM          Kali Uchis                 86
# 22   4oUHIQIBe0LHzYfvXNW4QM       Morgan Wallen                 91
# 21   0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida                 91
# 20   3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon                 87
# 2    0du5cEVh5yTK9QJze8zA0C          Bruno Mars                 96
# 23   246dkjvS1zLTtiykXe5h60         Post Malone                 91
# 4    4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator                 95
# 7    55Aa2cqylxrFIXC767Z865           Lil Wayne                 88
# 15   7GlBOeep6PqTfFi59PTUUN       Chappell Roan                 89
# 10   1oSPZhvZMIrWW5I41kPkkY               Jimin                 89
# 12   3eVa5w3URK5duf6eyVDbu9                ROSÉ                 84
# 19   3y2cIKLjiOlp1Np37WiUdH           Shaboozey                 80
# 11   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter                 94
# 24   22wbnEMDvgVIAGdFeek6ET        Benson Boone                 86
# 5    2qoQgPAilErOKCwE2Y8wOG            GloRilla                 82
# 6    3DbwFQlvLxRSi2uX8mf81A           Sexyy Red                 80
# 17   67FB4n52MgexGQIG8s0yUH          Lola Young                 74
#
#                          genre country_code
# 195      alternative americana           AU
# 187        classic country pop           AU
# 191   classic oklahoma country           AU
# 199   classic oklahoma country           AU
# 180       contemporary country           AU
# 186       contemporary country           AU
# 176       contemporary country           AU
# 188       contemporary country           AU
# 196       contemporary country           AU
# 177       contemporary country           AU
# 184       contemporary country           AU
# 183       contemporary country           AU
# 190                    country           AU
# 182                country pop           AU
# 178                country rap           AU
# 175                    dfw rap           AU
# 194                   jam band           AU
# 193         modern country pop           AU
# 198         modern country pop           AU
# 197                 pov: indie           AU
# 30                       alt z           BR
# 42           alternative dance           BR
# 35                     art pop           BR
# 31                     art pop           BR
# 44                 atl hip hop           BR
# 34                 bedroom pop           BR
# 43   canadian contemporary r&b           BR
# 26   canadian contemporary r&b           BR
# 45               colombian pop           BR
# 46        contemporary country           BR
# 48                     corrido           BR
# 47                     corrido           BR
# 32                   dance pop           BR
# 49                     dfw rap           BR
# 41                gangster rap           BR
# 25                     hip hop           BR
# 29                     hip hop           BR
# 40                   indie pop           BR
# 39                       k-pop           BR
# 37                       k-pop           BR
# 36                         pop           BR
# 27            southern hip hop           BR
# 28                  trap queen           BR
# 38                      uk pop           BR
# 50                       alt z           DE
# 59                     art pop           DE
# 51                     art pop           DE
# 64                 atl hip hop           DE
# 53                 bedroom pop           DE
# 63   canadian contemporary r&b           DE
# 58   canadian contemporary r&b           DE
# 66               colombian pop           DE
# 72        contemporary country           DE
# 71                     corrido           DE
# 70                     corrido           DE
# 52                   dance pop           DE
# 73                     dfw rap           DE
# 54                     hip hop           DE
# 57                     hip hop           DE
# 65                   indie pop           DE
# 60                       k-pop           DE
# 62                       k-pop           DE
# 69          modern country pop           DE
# 61                         pop           DE
# 74       singer-songwriter pop           DE
# 55            southern hip hop           DE
# 56                  trap queen           DE
# 67                      uk pop           DE
# 144           arab alternative           EG
# 134                   arab pop           EG
# 140                   arab pop           EG
# 142                   arab pop           EG
# 138                   arab pop           EG
# 126                   arab pop           EG
# 143                   arab pop           EG
# 147                   arab pop           EG
# 149                   arab pop           EG
# 135       egyptian alternative           EG
# 145       egyptian alternative           EG
# 141           egyptian hip hop           EG
# 127           egyptian hip hop           EG
# 132           egyptian hip hop           EG
# 146           egyptian hip hop           EG
# 148               egyptian pop           EG
# 133              egyptian trap           EG
# 131              egyptian trap           EG
# 130         egyptian viral pop           EG
# 125         egyptian viral pop           EG
# 139                 mahraganat           EG
# 136                     shaabi           EG
# 95             adult standards           GB
# 94             adult standards           GB
# 76             adult standards           GB
# 82                  album rock           GB
# 86              austrian choir           GB
# 99                    boy band           GB
# 83                british soul           GB
# 91                 celtic punk           GB
# 90                classic rock           GB
# 93                classic rock           GB
# 84                classic rock           GB
# 81              classic uk pop           GB
# 97        contemporary country           GB
# 96                   dance pop           GB
# 89                     europop           GB
# 85                experimental           GB
# 77                   glam rock           GB
# 80                   glam rock           GB
# 78                   glam rock           GB
# 75                   glam rock           GB
# 79                new romantic           GB
# 92                new wave pop           GB
# 98            progressive rock           GB
# 218         canzone napoletana           ID
# 203             drill italiana           ID
# 220           emo rap italiano           ID
# 214          italian adult pop           ID
# 223          italian adult pop           ID
# 222          italian adult pop           ID
# 209            italian hip hop           ID
# 216            italian hip hop           ID
# 207            italian hip hop           ID
# 212            italian hip hop           ID
# 219            italian hip hop           ID
# 221            italian hip hop           ID
# 213            italian hip hop           ID
# 215            italian hip hop           ID
# 208            italian hip hop           ID
# 224            italian hip hop           ID
# 205            italian hip hop           ID
# 200                italian pop           ID
# 202                italian pop           ID
# 201                italian pop           ID
# 206        pop virale italiano           ID
# 217                  reggaeton           ID
# 236            black americana           IN
# 235                    brostep           IN
# 229   classic oklahoma country           IN
# 230      classic texas country           IN
# 227       contemporary country           IN
# 231       contemporary country           IN
# 237       contemporary country           IN
# 232       contemporary country           IN
# 240       contemporary country           IN
# 244       contemporary country           IN
# 247       contemporary country           IN
# 243                country rap           IN
# 226                    dfw rap           IN
# 225         modern country pop           IN
# 239         modern country pop           IN
# 233         modern country pop           IN
# 238         modern country pop           IN
# 249         modern country pop           IN
# 245         modern country pop           IN
# 242               ohio hip hop           IN
# 234                        pop           IN
# 248                 pov: indie           IN
# 100                      alt z           IT
# 109                    art pop           IT
# 101                    art pop           IT
# 114                atl hip hop           IT
# 103                bedroom pop           IT
# 113  canadian contemporary r&b           IT
# 108  canadian contemporary r&b           IT
# 116              colombian pop           IT
# 122       contemporary country           IT
# 121                    corrido           IT
# 120                    corrido           IT
# 102                  dance pop           IT
# 123                    dfw rap           IT
# 104                    hip hop           IT
# 107                    hip hop           IT
# 115                  indie pop           IT
# 110                      k-pop           IT
# 112                      k-pop           IT
# 119         modern country pop           IT
# 111                        pop           IT
# 124      singer-songwriter pop           IT
# 105           southern hip hop           IT
# 106                 trap queen           IT
# 117                     uk pop           IT
# 150                      alt z           NG
# 159                    art pop           NG
# 151                    art pop           NG
# 164                atl hip hop           NG
# 153                bedroom pop           NG
# 163  canadian contemporary r&b           NG
# 158  canadian contemporary r&b           NG
# 166              colombian pop           NG
# 172       contemporary country           NG
# 171                    corrido           NG
# 170                    corrido           NG
# 152                  dance pop           NG
# 173                    dfw rap           NG
# 154                    hip hop           NG
# 157                    hip hop           NG
# 165                  indie pop           NG
# 160                      k-pop           NG
# 162                      k-pop           NG
# 169         modern country pop           NG
# 161                        pop           NG
# 174      singer-songwriter pop           NG
# 155           southern hip hop           NG
# 156                 trap queen           NG
# 167                     uk pop           NG
# 250                      alt z           SA
# 259                    art pop           SA
# 251                    art pop           SA
# 264                atl hip hop           SA
# 253                bedroom pop           SA
# 263  canadian contemporary r&b           SA
# 258  canadian contemporary r&b           SA
# 266              colombian pop           SA
# 272       contemporary country           SA
# 271                    corrido           SA
# 270                    corrido           SA
# 252                  dance pop           SA
# 273                    dfw rap           SA
# 254                    hip hop           SA
# 257                    hip hop           SA
# 265                  indie pop           SA
# 260                      k-pop           SA
# 262                      k-pop           SA
# 269         modern country pop           SA
# 261                        pop           SA
# 274      singer-songwriter pop           SA
# 255           southern hip hop           SA
# 256                 trap queen           SA
# 267                     uk pop           SA
# 0                        alt z           US
# 9                      art pop           US
# 1                      art pop           US
# 14                 atl hip hop           US
# 3                  bedroom pop           US
# 13   canadian contemporary r&b           US
# 8    canadian contemporary r&b           US
# 16               colombian pop           US
# 22        contemporary country           US
# 21                     corrido           US
# 20                     corrido           US
# 2                    dance pop           US
# 23                     dfw rap           US
# 4                      hip hop           US
# 7                      hip hop           US
# 15                   indie pop           US
# 10                       k-pop           US
# 12                       k-pop           US
# 19          modern country pop           US
# 11                         pop           US
# 24       singer-songwriter pop           US
# 5             southern hip hop           US
# 6                   trap queen           US
# 17                      uk pop           US
